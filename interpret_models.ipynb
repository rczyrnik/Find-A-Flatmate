# %%
import pickle

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)
    
results = pd.DataFrame(load_obj('gs_random_forest'))
# results.columns=["recall_mean","precision_mean","f1_mean","recall_std","precision_std","f1_std"]

# %%
results
# Out:
#     mean_fit_time  mean_score_time  mean_test_score param_min_samples_split  \
# 0        0.804462         0.011851         0.139339                       2
# 1        0.546055         0.013261         0.149842                       3
# 2        0.527401         0.012304         0.134086                       4
# 3        0.574739         0.015070         0.138844                       5
# 4        0.637898         0.020196         0.126898                       6
# 5        0.618560         0.017123         0.151406                       7
# 6        0.631755         0.016859         0.128852                       8
# 7        0.692684         0.014997         0.118950                       9
# 8        0.733779         0.017425         0.120531                      10
# 9        0.934120         0.034296         0.135796                      11
# 10       0.694040         0.017439         0.113990                      12
# ...

# %%
plt.bar(results.T.iloc[3], results.mean_test_score, yerr=results.std_test_score)
plt.show()
